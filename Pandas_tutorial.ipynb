# %% [markdown]
# <a href="https://colab.research.google.com/github/ns-m/data_analysis/blob/main/Pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/edu.fa.ru/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.DataFrame.from_dict({'first':['one', 'two'], 'second':[3,4]})

# %%
df2
# Out:
#   first  second
# 0   one       3
# 1   two       4

# %%
df.to_json('/content/drive/MyDrive/edu.fa.ru/titanic_2.json')
df.to_csv('/content/drive/MyDrive/edu.fa.ru/titanic_2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'].shape
# Out:
# (891,)

# %%
df[['Name', 'Age']].head(5)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df[['Age', 'Name']].head(5)
# Out:
#     Age                                               Name
# 0  22.0                            Braund, Mr. Owen Harris
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0                             Heikkinen, Miss. Laina
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0                           Allen, Mr. William Henry

# %%
df.loc[[5, 7, 14], ['Age', 'Name']]
# Out:
#      Age                                  Name
# 5    NaN                      Moran, Mr. James
# 7    2.0        Palsson, Master. Gosta Leonard
# 14  14.0  Vestrom, Miss. Hulda Amanda Adolfina

# %%
df.iloc[[5, 7, 14], [4, 5]]
# Out:
#        Sex   Age
# 5     male   NaN
# 7     male   2.0
# 14  female  14.0

# %%
df.iloc[5:14, :6]
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
#
#                                                  Name     Sex   Age
# 5                                    Moran, Mr. James    male   NaN
# 6                             McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master. Gosta Leonard    male   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0
# 12                     Saundercock, Mr. William Henry    male  20.0
# ...

# %%
df[df['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df['Age'] < 18
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isin([12,13,14,15,16])]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 39            40         1       3              Nicola-Yarred, Miss. Jamila
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 86            87         0       3                   Ford, Mr. William Neal
# 125          126         1       3             Nicola-Yarred, Master. Elias
# 138          139         0       3                      Osen, Mr. Olaf Elon
# 156          157         1       3         Gilnagh, Miss. Katherine "Katie"
# 208          209         1       3                Carr, Miss. Helen "Ellen"
# 220          221         1       3           Sunderland, Mr. Victor Francis
# ...

# %%
df[(df['Age'].isin([12,13,14,15,16])) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 39            40         1       3              Nicola-Yarred, Miss. Jamila
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 156          157         1       3         Gilnagh, Miss. Katherine "Katie"
# 208          209         1       3                Carr, Miss. Helen "Ellen"
# 329          330         1       1             Hippach, Miss. Jean Gertrude
# 435          436         1       1                Carter, Miss. Lucile Polk
# 446          447         1       2        Mellinger, Miss. Madeleine Violet
# 504          505         1       1                    Maioni, Miss. Roberta
# ...

# %%
df[(df['Sex'] == 'male') & ((df['Age'] > 70) |  (df['Age'] < 10))]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 63            64         0       3
# 78            79         1       2
# 96            97         0       1
# 116          117         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# 489          490         1       3
# 493          494         0       1
# 549          550         1       2
# ...

# %%
df['Age'].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
df.loc[df['Age'].isna(), 'Name']
# Out:
# 5                              Moran, Mr. James
# 17                 Williams, Mr. Charles Eugene
# 19                      Masselmani, Mrs. Fatima
# 26                      Emir, Mr. Farred Chehab
# 28                O'Dwyer, Miss. Ellen "Nellie"
#                          ...
# 859                            Razi, Mr. Raihed
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 177, dtype: object

# %%
df.sort_values('Age').head(15)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
# ...

# %%
df.sort_values(['Age', 'Name'], ascending=[False, True]).head(15)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 33            34         0       2                 Wheadon, Mr. Edward H
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 438          439         0       1                     Fortune, Mr. Mark
# ...

# %%
df_copy = df.copy(deep=True)

# %%
conc_df1 = pd.concat([df, df_copy])

# %%
conc_df1.shape
# Out:
# (1782, 12)

# %%
df.shape
# Out:
# (891, 12)

# %%
conc_df2 = pd.concat([df, df_copy], axis=1)

# %%
conc_df2.shape
# Out:
# (891, 24)

# %%
temp_df = pd.DataFrame(index=df.index)
temp_df['PassengerId'] = df['PassengerId']
temp_df['evenId'] = temp_df['PassengerId'].apply(lambda x: x% 2 == 0)

# %%
temp_df
# Out:
#      PassengerId  evenId
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 886          887   False
# 887          888    True
# 888          889   False
# 889          890    True
# 890          891   False
#
# [891 rows x 2 columns]

# %%
pd.merge(df, temp_df, how='inner')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df['Cabin'].count()
# Out:
# 204

# %%
df['Age'].mean(), df['Age'].median()
# Out:
# (29.69911764705882, 28.0)

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df.groupby(['Sex', 'Survived'])['Age'].agg(['mean', 'min', 'max'])
# Out:
#                       mean   min   max
# Sex    Survived
# female 0         25.046875  2.00  57.0
#        1         28.847716  0.75  63.0
# male   0         31.618056  1.00  74.0
#        1         27.276022  0.42  80.0

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 'male') & (df['Age'] == df['Age'].max())]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-71-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
df['Age'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde', xlim=[0, 100])
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby('Sex')['Age'].plot(kind='kde', xlim=[0, 100], legend=True)
# Out:
# Sex
# female    Axes(0.125,0.11;0.775x0.77)
# male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
tmp2_df = df.copy(deep=True)

# %%
tmp2_df['Pclass'] = 1

# %%
tmp2_df['Pclass'].value_counts()
# Out:
# 1    891
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
tmp2_df['isAdult'] = tmp2_df['Age']>=18
tmp2_df['isChild'] = tmp2_df['Age']<18

# %%
tmp2_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       1
# 1             2         1       1
# 2             3         1       1
# 3             4         1       1
# 4             5         0       1
# 5             6         0       1
# 6             7         0       1
# 7             8         0       1
# 8             9         1       1
# 9            10         1       1
# 10           11         1       1
# 11           12         1       1
# 12           13         0       1
# 13           14         0       1
# 14           15         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
tmp2_df['isChildSurvived'] = tmp2_df['isChild']
tmp2_df.loc[tmp2_df['Survived'] == 0, 'isChildSurvived'] = False

# %%
tmp2_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       1
# 1             2         1       1
# 2             3         1       1
# 3             4         1       1
# 4             5         0       1
# 5             6         0       1
# 6             7         0       1
# 7             8         0       1
# 8             9         1       1
# 9            10         1       1
# 10           11         1       1
# 11           12         1       1
# 12           13         0       1
# 13           14         0       1
# 14           15         0       1
# 15           16         1       1
# 16           17         0       1
# 17           18         1       1
# 18           19         0       1
# 19           20         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
tmp2_df.rename(
    columns={'isChildSurvived': 'ChildSurvived'}
).head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       1  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  isAdult  isChild  ChildSurvived
# 0      0  A/5 21171  7.25   NaN        S     True    False          False

# %%
tmp2_df.rename(columns=str.lower).head(1)
# Out:
#    passengerid  survived  pclass                     name   sex   age  sibsp  \
# 0            1         0       1  Braund, Mr. Owen Harris  male  22.0      1
#
#    parch     ticket  fare cabin embarked  isadult  ischild  ischildsurvived
# 0      0  A/5 21171  7.25   NaN        S     True    False            False

# %%
tmp2_df['lower_case_name'] = tmp2_df['Name'].apply(lambda x: x.lower())

# %%
tmp2_df['lower_case_name']
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: lower_case_name, Length: 891, dtype: object

# %%
tmp2_df['lower_case_name2'] = tmp2_df['Name'].str.lower()

# %%
tmp2_df['lower_case_name2']
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: lower_case_name2, Length: 891, dtype: object
