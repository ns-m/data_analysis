# %% [markdown]
# <a href="https://colab.research.google.com/github/ns-m/data_analysis/blob/main/Linear_Regression_Machine_learning_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Линейная регрессия (англ. Linear regression) — используемая в статистике регрессионная модель зависимости одной (объясняемой, зависимой) переменной
# y от другой или нескольких других переменных (факторов, регрессоров, независимых переменных) x с линейной функцией зависимости.
# Метод наименьших квадратов
# Начнём с простейшего двумерного случая. Пусть нам даны точки на плоскости {(x_1,y_1),\cdots,(x_N,y_N)\} и мы ищем такую аффинную функцию
# f(x) = m * x + b
# m - степень наклона. b - это значение для построения следующнй точки на прямой (если положительное то вверх, если отрицательное то вниз)
# чтобы ее график ближе всего находился к точкам. Таким образом, наш базис состоит из константной функции и линейной (1, x).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cost_revenue_clean.csv')

# %%
df.head()
# Out:
#    production_budget_usd  worldwide_gross_usd
# 0                1000000                   26
# 1                  10000                  401
# 2                 400000                  423
# 3                 750000                  450
# 4                  10000                  527

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5034 entries, 0 to 5033
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   production_budget_usd  5034 non-null   int64
#  1   worldwide_gross_usd    5034 non-null   int64
# dtypes: int64(2)
# memory usage: 78.8 KB

# %%
df.shape
# Out:
# (5034, 2)

# %%
df.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
plt.figure(figsize=(15,9))
plt.scatter(df.production_budget_usd, df.worldwide_gross_usd, alpha=0.6)
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.ylim(0, 3*(10**9))
plt.xlim(0, 45*(10**7))
# Out:
# (0.0, 450000000.0)

# %%
model = LinearRegression()

# %%
X = pd.DataFrame(df.production_budget_usd)
y = pd.DataFrame(df.worldwide_gross_usd)

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[3.11150918]])

# %%
model.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(15,9))
plt.scatter(df.production_budget_usd, df.worldwide_gross_usd, alpha=0.6)

plt.plot(X, model.predict(X), color = 'red', linewidth = 2)

plt.xlabel('Budget')
plt.ylabel('Gross')
plt.ylim(0, 3*(10**9))
plt.xlim(0, 45*(10**7))
# Out:
# (0.0, 450000000.0)

# %%
model.score(X, y)
# Out:
# 0.5496485356985729

# %%
model.predict([[20000000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[54993990.92958295]])
