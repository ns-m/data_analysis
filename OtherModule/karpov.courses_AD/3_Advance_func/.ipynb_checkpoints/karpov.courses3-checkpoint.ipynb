# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('./lesson_3_data__1_.csv', encoding='windows-1251')

# %%
df.head()
# Out:
#    Unnamed: 0                  tk  pl         dia        hs         tc  \
# 0        1242  120071109002055793   1  2007/11/09  0.505729  110000761
# 1        1243  120070601004053633   1  2007/06/01  0.588519  110000761
# 2        1244  120070928004076410   1  2007/09/28  0.785498   28491841
# 3        1245  120070616003074261   1  2007/06/16  0.550961   95931501
# 4        1246  120070519001018477   1  2007/05/19  0.804954   93265591
#
#         cta  id_art  id_subsubfam   id_subfam  ...   id_famn  id_seccion  \
# 0  11000076   21895  101070640100  1010706401  ...  10107064       10107
# 1  11000076   21816  101070640100  1010706401  ...  10107064       10107
# 2   2849184  562840  101070640100  1010706401  ...  10107064       10107
# 3   9593150   28914  101070640100  1010706401  ...  10107064       10107
# 4   9326559  159867  101070640100  1010706401  ...  10107064       10107
#
#    id_subagr  id_agr   vta  uni  id_artn                              art_sp  \
# ...

# %%
work_df = df[['tc', 'art_sp']]
work_df
# Out:
#                tc                              art_sp
# 0       110000761  MARAVILLA        500 G Store_Brand
# 1       110000761  FIDEO CABELLIN   500 G Store_Brand
# 2        28491841        SPAGUETTI Nє 5 500 G Brand_1
# 3        95931501       FIDEO FIDEUБ      500 Brand_7
# 4        93265591      MACARRONES  GRATINAR 5 Brand_2
# ...           ...                                 ...
# 48124    45518841      FIDEOS 0         500 G Brand_4
# 48125   110824211      PLUMAS 3         500 G Brand_4
# 48126  1408670389  MACARRONES       500 G Store_Brand
# 48127  1408670389  SPAGHETTI        500 G Store_Brand
# 48128    48582221  SPAGHETTINI      500 G Store_Brand
#
# [48129 rows x 2 columns]

# %%
work_df = work_df.rename(columns={'tc': 'user_id', 'art_sp': 'brand_info'})

# %%
work_df.head()
# Out:
#      user_id                          brand_info
# 0  110000761  MARAVILLA        500 G Store_Brand
# 1  110000761  FIDEO CABELLIN   500 G Store_Brand
# 2   28491841        SPAGUETTI Nє 5 500 G Brand_1
# 3   95931501       FIDEO FIDEUБ      500 Brand_7
# 4   93265591      MACARRONES  GRATINAR 5 Brand_2

# %%
def split_brand(data):
    return data.split(' ')[-1]

# %%
work_df['brand_name'] = work_df.brand_info.apply(split_brand)
work_df
# Out:
#           user_id                          brand_info   brand_name
# 0       110000761  MARAVILLA        500 G Store_Brand  Store_Brand
# 1       110000761  FIDEO CABELLIN   500 G Store_Brand  Store_Brand
# 2        28491841        SPAGUETTI Nє 5 500 G Brand_1      Brand_1
# 3        95931501       FIDEO FIDEUБ      500 Brand_7      Brand_7
# 4        93265591      MACARRONES  GRATINAR 5 Brand_2      Brand_2
# ...           ...                                 ...          ...
# 48124    45518841      FIDEOS 0         500 G Brand_4      Brand_4
# 48125   110824211      PLUMAS 3         500 G Brand_4      Brand_4
# 48126  1408670389  MACARRONES       500 G Store_Brand  Store_Brand
# 48127  1408670389  SPAGHETTI        500 G Store_Brand  Store_Brand
# 48128    48582221  SPAGHETTINI      500 G Store_Brand  Store_Brand
#
# [48129 rows x 3 columns]

# %%
work_df.brand_info.apply(lambda x: x.split(' ')[-1])
# Out:
# 0        Store_Brand
# 1        Store_Brand
# 2            Brand_1
# 3            Brand_7
# 4            Brand_2
#             ...
# 48124        Brand_4
# 48125        Brand_4
# 48126    Store_Brand
# 48127    Store_Brand
# 48128    Store_Brand
# Name: brand_info, Length: 48129, dtype: object

# %%
users_purchases = work_df.groupby('user_id', as_index=False) \
.agg({'brand_name': 'count'}) \
.rename(columns={'brand_name': 'purchases'}) \
.sort_values('purchases', ascending=False)
users_purchases
# Out:
#           user_id  purchases
# 6326     62325711         60
# 3376     19317282         55
# 670       1228091         52
# 1377      3133061         51
# 3965     23440561         47
# ...           ...        ...
# 6479     64377021          1
# 6476     64375071          1
# 6475     64373901          1
# 6471     64283361          1
# 11763  1408849249          1
#
# [11764 rows x 2 columns]

# %%
users_purchases.shape
# Out:
# (11764, 2)

# %%
users_purchases.describe()
# Out:
#             user_id     purchases
# count  1.176400e+04  11764.000000
# mean   7.690517e+07      4.091210
# std    1.622210e+08      4.573143
# min   -1.236395e+09      1.000000
# 25%    1.503761e+07      1.000000
# 50%    4.682179e+07      2.000000
# 75%    9.311601e+07      5.000000
# max    1.408849e+09     60.000000

# %%
users_purchases = users_purchases \
.query('purchases >= 5') \
.sort_values('purchases', ascending=False)
users_purchases
# Out:
#          user_id  purchases
# 6326    62325711         60
# 3376    19317282         55
# 670      1228091         52
# 1377     3133061         51
# 3965    23440561         47
# ...          ...        ...
# 3463    19776171          5
# 10218  112028971          5
# 8577    90849701          5
# 4610    28315352          5
# 1647     4755151          5
#
# [3383 rows x 2 columns]

# %%
users_purchases.describe()
# Out:
#             user_id    purchases
# count  3.383000e+03  3383.000000
# mean   6.421500e+07     9.320130
# std    1.504830e+08     5.623993
# min    1.031000e+03     5.000000
# 25%    8.871271e+06     6.000000
# 50%    2.842547e+07     7.000000
# 75%    8.542964e+07    11.000000
# max    1.408810e+09    60.000000

# %%
users_purchases_details = work_df.groupby(['user_id', 'brand_name'], as_index=False) \
.agg({'brand_info': 'count'}) \
.sort_values(['user_id', 'brand_info'], ascending= [True, False]) \
.groupby('user_id') \
.head(1) \
.rename(columns={'brand_name': 'favore_brand', 'brand_info': 'favore_brand_purchases'})
users_purchases_details
# Out:
#           user_id favore_brand  favore_brand_purchases
# 0     -1236394515      Brand_4                       1
# 2            1031  Store_Brand                       5
# 3            4241      Brand_4                       3
# 5           17311      Brand_4                       2
# 6           17312      Brand_1                       1
# ...           ...          ...                     ...
# 18183  1408817589  Store_Brand                       2
# 18184  1408825059      Brand_1                       1
# 18185  1408832719      Brand_4                       3
# 18186  1408840919  Store_Brand                       1
# 18187  1408849249  Store_Brand                       1
#
# [11764 rows x 3 columns]

# %%
users_unique_brands = work_df.groupby('user_id', as_index=False) \
.agg({'brand_name': pd.Series.nunique}) \
.rename(columns={'brand_name': 'unique_brands'})
users_unique_brands
# Out:
#           user_id  unique_brands
# 0     -1236394515              1
# 1            1031              2
# 2            4241              2
# 3           17311              1
# 4           17312              2
# ...           ...            ...
# 11759  1408817589              2
# 11760  1408825059              1
# 11761  1408832719              1
# 11762  1408840919              1
# 11763  1408849249              1
#
# [11764 rows x 2 columns]

# %%
loyality_df = users_purchases \
.merge(users_unique_brands, on='user_id') \
.merge(users_purchases_details, on='user_id') \
.sort_values('user_id')

# %%
loyality_df
# Out:
#          user_id  purchases  unique_brands favore_brand  \
# 2345        1031          6              2  Store_Brand
# 2987        4241          5              2      Brand_4
# 1943       25971          7              2  Store_Brand
# 56         40911         27              5      Brand_4
# 2953       45181          5              4  Store_Brand
# ...          ...        ...            ...          ...
# 2676  1408767189          5              1      Brand_4
# 936   1408783189         10              2  Store_Brand
# 2548  1408783379          6              2      Brand_1
# 1554  1408798879          8              3  Store_Brand
# 1335  1408810219          9              2      Brand_2
#
#       favore_brand_purchases
# 2345                       5
# 2987                       3
# 1943                       5
# 56                        19
# 2953                       2
# ...                      ...
# 2676                       5
# 936                        8
# ...

# %%
loyal_users = loyality_df[loyality_df.unique_brands == 1]
loyal_users
# Out:
#          user_id  purchases  unique_brands favore_brand  \
# 472        86281         14              1      Brand_4
# 2410       94961          6              1      Brand_4
# 1317      132061          9              1      Brand_4
# 2549      134281          6              1      Brand_4
# 708       157311         12              1      Brand_4
# ...          ...        ...            ...          ...
# 1257  1010244089          9              1  Store_Brand
# 2736  1010247239          5              1      Brand_4
# 3253  1010274559          5              1      Brand_4
# 2842  1110091379          5              1      Brand_1
# 2676  1408767189          5              1      Brand_4
#
#       favore_brand_purchases
# 472                       14
# 2410                       6
# 1317                       9
# 2549                       6
# 708                       12
# ...                      ...
# 1257                       9
# 2736                       5
# ...

# %%
loyality_df['loyalty_score'] = loyality_df.favore_brand_purchases / loyality_df.purchases
loyality_df.head()
# Out:
#       user_id  purchases  unique_brands favore_brand  favore_brand_purchases  \
# 2345     1031          6              2  Store_Brand                       5
# 2987     4241          5              2      Brand_4                       3
# 1943    25971          7              2  Store_Brand                       5
# 56      40911         27              5      Brand_4                      19
# 2953    45181          5              4  Store_Brand                       2
#
#       loyalty_score
# 2345       0.833333
# 2987       0.600000
# 1943       0.714286
# 56         0.703704
# 2953       0.400000

# %%
ax = sns.distplot(loyality_df.loyalty_score, kde=False)

# %%
split_loyalty_brands = loyality_df.groupby('favore_brand', as_index=False) \
.agg({'loyalty_score': 'median', 'user_id': 'count'})
split_loyalty_brands
# Out:
#   favore_brand  loyalty_score  user_id
# 0      Brand_1       0.679487      410
# 1      Brand_2       0.600000       88
# 2      Brand_3       0.500000      115
# 3      Brand_4       0.818182     2041
# 4      Brand_5       0.600000        5
# 5      Brand_7       0.444444        9
# 6  Store_Brand       0.750000      715

# %%
ax = sns.barplot(x='favore_brand', y='loyalty_score', data=split_loyalty_brands)

# %%
ax = sns.barplot(x='favore_brand', y='user_id', data=split_loyalty_brands)

# %% [markdown]
# ## Homeworks

# %%
names = 'Name1 Surname1, Name2 Surname2, Name3 Surname3'

# %%
names_list = names.split(', ')
names_list
# Out:
# ['Name1 Surname1', 'Name2 Surname2', 'Name3 Surname3']

# %%
df_hw3 = pd.read_csv('https://stepik.org/media/attachments/lesson/359209/companies.csv', sep=';')

# %%
taxi = pd.read_csv('https://stepik.org/media/attachments/lesson/359240/taxi_peru.csv', \
                   sep=';', parse_dates=['start_at', 'end_at', 'arrived_at'])
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23111 entries, 0 to 23110
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   journey_id        23111 non-null  object
#  1   user_id           23111 non-null  object
#  2   driver_id         19726 non-null  object
#  3   taxi_id           19726 non-null  object
#  4   icon              23111 non-null  object
#  5   start_type        23111 non-null  object
#  6   start_at          23111 non-null  datetime64[ns]
#  7   start_lat         23111 non-null  object
#  8   start_lon         23111 non-null  object
#  9   end_at            22835 non-null  datetime64[ns]
#  10  end_lat           23111 non-null  object
#  11  end_lon           23111 non-null  object
#  12  end_state         23099 non-null  object
#  13  driver_start_lat  19621 non-null  object
#  14  driver_start_lon  19621 non-null  object
# ...

# %%
source_score = taxi.groupby('source', as_index=False).agg({'user_id': 'count'}).sort_values('user_id')
source_score
# Out:
#     source  user_id
# 1      Wap      136
# 2     iPad      571
# 0  Android     4909
# 4      web     7631
# 3   iPhone     9741

# %%
source_score.user_id / source_score.user_id.sum() * 100
# Out:
# 1     0.591613
# 2     2.483905
# 0    21.354620
# 4    33.195580
# 3    42.374282
# Name: user_id, dtype: float64

# %%
ax = sns.barplot(x='source', y='user_id', data=source_score)

# %%
ax = sns.countplot(taxi['icon'])

# %%
ax = sns.countplot(data=taxi, x="source", hue="end_state")

# %%
taxi.driver_score.value_counts()
# Out:
# 5.0    4499
# 4.0    1674
# 0.0    1094
# 3.0     227
# 1.0      94
# 2.0      62
# Name: driver_score, dtype: int64

# %%
taxi.driver_score.value_counts().sum()
# Out:
# 7650

# %%
driver_score_counts = pd.DataFrame((taxi.driver_score.value_counts() / taxi.driver_score.value_counts().sum()).mul(100).round(2))
driver_score_counts = driver_score_counts.reset_index()
driver_score_counts = driver_score_counts.rename(columns={'index': 'driver_score', 'driver_score': 'percentage'}) \
.sort_values('driver_score', ascending= True)
driver_score_counts
# Out:
#    driver_score  percentage
# 2           0.0       14.30
# 4           1.0        1.23
# 5           2.0        0.81
# 3           3.0        2.97
# 1           4.0       21.88
# 0           5.0       58.81

# %%
ax = sns.barplot(x='driver_score', y='percentage', data=driver_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='Driver score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %%
rider_score_counts = pd.DataFrame((taxi.rider_score.value_counts() / taxi.rider_score.value_counts().sum()).mul(100).round(2))
rider_score_counts = rider_score_counts.reset_index()
rider_score_counts = rider_score_counts.rename(columns={'index': 'rider_score', 'rider_score': 'percentage'}) \
.sort_values('rider_score', ascending= True)
rider_score_counts
# Out:
#    rider_score  percentage
# 2          0.0        2.29
# 4          1.0        0.21
# 5          2.0        0.19
# 3          3.0        1.38
# 1          4.0        8.83
# 0          5.0       87.10

# %%
ax = sns.barplot(x='rider_score', y='percentage', data=rider_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='rider score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %%
df_user_data = pd.read_csv('https://stepik.org/media/attachments/lesson/360348/user_data.csv')

# %%
df_logs = pd.read_csv('https://stepik.org/media/attachments/lesson/360348/logs.csv')

# %%
df_user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2954 entries, 0 to 2953
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   client   2954 non-null   int64
#  1   premium  2954 non-null   bool
#  2   age      2954 non-null   int64
# dtypes: bool(1), int64(2)
# memory usage: 49.2 KB

# %%
df_user_data[df_user_data.isnull()].count()
# Out:
# client     0
# premium    0
# age        0
# dtype: int64

# %%
df_user_data.describe()
# Out:
#              client          age
# count   2954.000000  2954.000000
# mean   50767.886594    44.196005
# std    28800.505847    14.248336
# min       40.000000    20.000000
# 25%    25639.500000    32.000000
# 50%    51569.500000    44.000000
# 75%    75963.250000    56.000000
# max    99973.000000    69.000000

# %%
df_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   client    4500 non-null   int64
#  1   success   4500 non-null   bool
#  2   platform  4500 non-null   object
#  3   time      4500 non-null   int64
# dtypes: bool(1), int64(2), object(1)
# memory usage: 110.0+ KB

# %%
df_logs[df_logs.isnull()].count()
# Out:
# client      0
# success     0
# platform    0
# time        0
# dtype: int64

# %%
df_logs.describe()
# Out:
#              client          time
# count   4500.000000  4.500000e+03
# mean   50998.758000  1.585440e+09
# std    28374.472495  2.314866e+04
# min       40.000000  1.585400e+09
# 25%    27056.500000  1.585420e+09
# 50%    52659.000000  1.585440e+09
# 75%    76001.250000  1.585461e+09
# max    99993.000000  1.585480e+09

# %%
len(df_logs.platform.unique())
# Out:
# 3

# %%
df_logs.platform.nunique()
# Out:
# 3

# %%
success_users = df_logs[df_logs['success'] == True]
success_users
# Out:
#       client  success  platform        time
# 0      40177     True     phone  1585412212
# 1      61468     True     phone  1585425658
# 3       9961     True     phone  1585400189
# 4      10931     True  computer  1585468629
# 5      41928     True     phone  1585446772
# ...      ...      ...       ...         ...
# 4493   92584     True  computer  1585408896
# 4494   95152     True  computer  1585420263
# 4496   73299     True     phone  1585458370
# 4497    8967     True     phone  1585465121
# 4499   40921     True     phone  1585437692
#
# [3289 rows x 4 columns]

# %%
success_users.groupby('client', as_index=False) \
.agg({'success': 'count'}) \
.sort_values(['success', 'client'], ascending=[False, True]).head(10)
# Out:
#       client  success
# 332    12179       41
# 810    28719       41
# 1020   36165       41
# 1487   52870       41
# 1758   61468       41
# 1759   61473       41
# 2231   78349       41
# 2345   82563       41
# 2626   92584       41
# 1826   64064       40

# %%
success_users.client.value_counts()
# Out:
# 36165    41
# 61468    41
# 12179    41
# 61473    41
# 78349    41
#          ..
# 36194     1
# 57752     1
# 84618     1
# 53228     1
# 36864     1
# Name: client, Length: 2845, dtype: int64

# %%
success_users.platform.value_counts()
# Out:
# phone       2019
# computer    1090
# tablet       180
# Name: platform, dtype: int64

# %%
df_all_data = df_logs.merge(df_user_data, on='client')

# %%
df_all_data.head()
# Out:
#    client  success  platform        time  premium  age
# 0   61468     True     phone  1585425658    False   25
# 1   61468     True  computer  1585460504    False   25
# 2   61468     True  computer  1585430291    False   25
# 3   61468     True  computer  1585444317    False   25
# 4   61468     True     phone  1585441266    False   25

# %%
df_all_data[df_all_data['premium'] == True].platform.value_counts()
# Out:
# phone       246
# computer    150
# tablet       24
# Name: platform, dtype: int64

# %%
ax = sns.countplot(data=df_all_data, x="age", hue="premium")

# %%
ax = sns.distplot(df_all_data[df_all_data['premium'] == True].age)

# %%
ax = sns.distplot(df_all_data[df_all_data['premium'] == False].age)

# %%
success_users_group = pd.DataFrame(success_users.groupby('client', as_index=False) \
.agg({'success': 'count'}) \
.success.value_counts()) \
.reset_index() \
.rename(columns={'index': 'value_count', 'success': 'success_count'}) \
.sort_values('value_count', ascending=True)
success_users_group
# Out:
#    value_count  success_count
# 0            1           2791
# 1            2             43
# 3            3              1
# 4           40              1
# 2           41              9

# %%
ax = sns.lineplot(data=success_users_group, x='value_count' \
                 , y='success_count')

# %%
df_all_data.head()
# Out:
#    client  success  platform        time  premium  age
# 0   61468     True     phone  1585425658    False   25
# 1   61468     True  computer  1585460504    False   25
# 2   61468     True  computer  1585430291    False   25
# 3   61468     True  computer  1585444317    False   25
# 4   61468     True     phone  1585441266    False   25

# %%
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=df_all_data, x="age", hue='success')
